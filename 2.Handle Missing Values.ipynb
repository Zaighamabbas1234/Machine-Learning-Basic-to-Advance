# %% [markdown]
# Machine Learning:

# %% [markdown]
# Import library:

# %%
import pandas as pd

# %% [markdown]
# Import dataset:

# %%
df = pd.read_csv("Demo Data.csv")

# %% [markdown]
# Import dataset by using the directory:

# %%
df = pd.read_csv(r"E:\Datasets\Regression Dataset\Demo Data.csv")

# %% [markdown]
# Data Exploration:

# %%
print("First 5 Rows of the Dataset:")
display(df.head(5))
# Out:
# First 5 Rows of the Dataset:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
print("Last 5 Rows of the Dataset:")
display(df.tail(5))
# Out:
# Last 5 Rows of the Dataset:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %% [markdown]
# Note: The NAN shows the null values in the dataset.

# %%
print("Column Names:")
display(df.columns)
# Out:
# Column Names:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='str')

# %%
print("Data Types of Dataset Columns:")
print(df.dtypes)
# Out:
# Data Types of Dataset Columns:
# Name            str
# Team            str
# Number      float64
# Position        str
# Age         float64
# Height          str
# Weight      float64
# College         str
# Salary      float64
# dtype: object

# %%
rows, columns = df.shape
print("Number of Rows:", rows)
print("Number of Columns:", columns)
# Out:
# Number of Rows: 458
# Number of Columns: 9

# %%
print("Statistical Summary of the Dataset:")
display(df.describe())
# Out:
# Statistical Summary of the Dataset:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
print("Dataset Information:")
display(df.info())
# Out:
# Dataset Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    str
#  1   Team      457 non-null    str
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    str
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    str
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    str
#  8   Salary    446 non-null    float64
# dtypes: float64(4), str(5)
# memory usage: 32.4 KB
# None

# %% [markdown]
# Missing values:

# %%
df.isnull()
# Out:
#       Name   Team  Number  Position    Age  Height  Weight  College  Salary
# 0    False  False   False     False  False   False   False    False   False
# 1    False  False   False     False  False   False   False    False   False
# 2    False  False   False     False  False   False   False    False    True
# 3    False  False   False     False  False   False   False    False   False
# 4    False  False   False     False  False   False   False     True   False
# ..     ...    ...     ...       ...    ...     ...     ...      ...     ...
# 453  False  False   False     False  False   False   False    False   False
# 454  False  False   False     False  False   False   False     True   False
# 455  False  False   False     False  False   False   False     True   False
# 456  False  False   False     False  False   False   False    False   False
# 457   True   True    True      True   True    True    True     True    True
#
# [458 rows x 9 columns]

# %% [markdown]
# True mean missing value is present.
#
# False mean no missing value is present.

# %% [markdown]
# Count missing values:

# %%
df.isnull().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(104)

# %% [markdown]
# Percentage of null values by columns:

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# Name         0.218341
# Team         0.218341
# Number       0.218341
# Position     0.218341
# Age          0.218341
# Height       0.218341
# Weight       0.218341
# College     18.558952
# Salary       2.620087
# dtype: float64

# %% [markdown]
# Note: shape[0] shows the number of rows.
#
# Note: shape[1] shows the number of columns.

# %% [markdown]
# Overall percentage of null values in dataset:

# %%
df.isnull().sum().sum()/(df.shape[0]*df.shape[1])*100
# Out:
# np.float64(2.523047064531781)

# %% [markdown]
# Not null values:

# %%
df.notnull()
# Out:
#       Name   Team  Number  Position    Age  Height  Weight  College  Salary
# 0     True   True    True      True   True    True    True     True    True
# 1     True   True    True      True   True    True    True     True    True
# 2     True   True    True      True   True    True    True     True   False
# 3     True   True    True      True   True    True    True     True    True
# 4     True   True    True      True   True    True    True    False    True
# ..     ...    ...     ...       ...    ...     ...     ...      ...     ...
# 453   True   True    True      True   True    True    True     True    True
# 454   True   True    True      True   True    True    True    False    True
# 455   True   True    True      True   True    True    True    False    True
# 456   True   True    True      True   True    True    True     True    True
# 457  False  False   False     False  False   False   False    False   False
#
# [458 rows x 9 columns]

# %%
df.notnull().sum()
# Out:
# Name        457
# Team        457
# Number      457
# Position    457
# Age         457
# Height      457
# Weight      457
# College     373
# Salary      446
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# np.int64(4018)

# %%
df.notnull().sum()/df.shape[0]*100
# Out:
# Name        99.781659
# Team        99.781659
# Number      99.781659
# Position    99.781659
# Age         99.781659
# Height      99.781659
# Weight      99.781659
# College     81.441048
# Salary      97.379913
# dtype: float64

# %%
df.notnull().sum().sum()/(df.shape[0]*df.shape[1])*100
# Out:
# np.float64(97.47695293546822)

# %% [markdown]
# Data Visulaization:

# %% [markdown]
# Import Libraries:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Missing values visualization:

# %%
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# The white bars shows the missing values.

# %% [markdown]
# How to handle missing values?

# %% [markdown]
# Method 01: Delete the whole column.
#
# Method 02: Delete the rows that contain the missing values.

# %% [markdown]
# Method 01: Delete the whole column:

# %%
df.drop(columns=["College"], inplace=True)

# %%
print("First 5 Rows of the Dataset:")
display(df.head(5))
# Out:
# First 5 Rows of the Dataset:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#       Salary
# 0  7730337.0
# 1  6796117.0
# 2        NaN
# 3  1148640.0
# 4  5000000.0

# %%
rows, columns = df.shape
print("Number of Rows:", rows)
print("Number of Columns:", columns)
# Out:
# Number of Rows: 458
# Number of Columns: 8

# %% [markdown]
# Data Visualization:

# %%
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# Method 02: Delete the rows that contain the missing values.

# %%
df.dropna(inplace=True)

# %%
print("First 5 Rows of the Dataset:")
display(df.head(5))
# Out:
# First 5 Rows of the Dataset:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
#
#        Salary
# 0   7730337.0
# 1   6796117.0
# 3   1148640.0
# 4   5000000.0
# 5  12000000.0

# %%
rows, columns = df.shape
print("Number of Rows:", rows)
print("Number of Columns:", columns)
# Out:
# Number of Rows: 446
# Number of Columns: 8

# %% [markdown]
# Data Visualization:

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
rows_lost = 458 - 446
columns_lost = 9 - 8

print("Number of rows lost:", rows_lost)
print("Number of columns lost:", columns_lost)
# Out:
# Number of rows lost: 12
# Number of columns lost: 1

# %% [markdown]
# Note:
#
# Always try to fill the missing values.
#
# Drop rows and columns is not a good pratice.
#
# We do not know that how the important data that we dropped form the dataset.
